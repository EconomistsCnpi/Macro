# %%
import pandas as pd 
import ipeadatapy as ip

# %%
table=ip.timeseries(series='MPAS12_RESPRGPS12')
table['VALUE (R$)'].plot()
# Out:
#                          CODE                   RAW DATE  DAY  MONTH  YEAR  \
# DATE
# 2003-02-01  MPAS12_RESPRGPS12  2003-02-01T00:00:00-02:00    1      2  2003
# 2003-03-01  MPAS12_RESPRGPS12  2003-03-01T00:00:00-03:00    1      3  2003
# 2003-04-01  MPAS12_RESPRGPS12  2003-04-01T00:00:00-03:00    1      4  2003
# 2003-05-01  MPAS12_RESPRGPS12  2003-05-01T00:00:00-03:00    1      5  2003
# 2003-06-01  MPAS12_RESPRGPS12  2003-06-01T00:00:00-03:00    1      6  2003
# ...                       ...                        ...  ...    ...   ...
# 2024-05-01  MPAS12_RESPRGPS12  2024-05-01T00:00:00-03:00    1      5  2024
# 2024-06-01  MPAS12_RESPRGPS12  2024-06-01T00:00:00-03:00    1      6  2024
# 2024-07-01  MPAS12_RESPRGPS12  2024-07-01T00:00:00-03:00    1      7  2024
# 2024-08-01  MPAS12_RESPRGPS12  2024-08-01T00:00:00-03:00    1      8  2024
# 2024-09-01  MPAS12_RESPRGPS12  2024-09-01T00:00:00-03:00    1      9  2024
#
#               VALUE (R$)
# DATE
# 2003-02-01 -1.083670e+06
# ...

# %%
table=table.query('index >= "2010-01-01"')
table['VALUE (R$)'].min()
# Out:
# np.float64(-61027084.29995)
