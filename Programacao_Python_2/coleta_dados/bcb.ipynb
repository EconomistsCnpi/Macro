# %%
import pandas as pd 
from bcb import sgs

# %%
dados_igpm=sgs.get(codes={'IGPM':189},start='2022-01-01')

# %%
dados_igpm.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
selic_expectativa=pd.read_csv("https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoSelic?$top=100&$filter=Data%20ge%20'2015-01-01'&$format=text/csv")

# %%
selic_expectativa
# Out:
#    Indicador        Data  Reuniao  ... Maximo numeroRespondentes baseCalculo
# 0      Selic  2024-11-22  R7/2026  ...     14                 92           0
# 1      Selic  2024-11-22  R7/2026  ...     14                 77           1
# 2      Selic  2024-11-22  R6/2026  ...     14                116           0
# 3      Selic  2024-11-22  R6/2026  ...     14                 88           1
# 4      Selic  2024-11-22  R5/2026  ...     14                118           0
# ..       ...         ...      ...  ...    ...                ...         ...
# 95     Selic  2024-11-19  R8/2024  ...     12                 56           1
# 96     Selic  2024-11-18  R7/2026  ...     13                 66           0
# 97     Selic  2024-11-18  R7/2026  ...     13                 50           1
# 98     Selic  2024-11-18  R6/2026  ...     13                113           0
# 99     Selic  2024-11-18  R6/2026  ...     13                 56           1
#
# [100 rows x 10 columns]

# %%
selic_json=pd.read_json(path_or_buf='https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoTop5Mensais?$top=100&$format=json')

# %%
import requests
def get_json(url):
    response=requests.get(url)
    data=response.json()
    return {'Indicador': data['Indicador'], 'Data': data['Data']}

# %%
import requests
url='https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoTop5Mensais?$top=100&$format=json'
response=requests.get(url)
data_json=response.json()
df=pd.DataFrame(data_json['value'])
df
# Out:
#    Indicador        Data DataReferencia  ... DesvioPadrao  Minimo  Maximo
# 0     IGP-DI  2001-11-06        10/2001  ...         None    None    None
# 1     IGP-DI  2001-11-06        11/2001  ...         None    None    None
# 2     IGP-DI  2001-11-06        12/2001  ...         None    None    None
# 3     IGP-DI  2001-11-06        01/2002  ...         None    None    None
# 4     IGP-DI  2001-11-06        02/2002  ...         None    None    None
# ..       ...         ...            ...  ...          ...     ...     ...
# 95    IGP-DI  2001-11-09        09/2002  ...         None    None    None
# 96    IGP-DI  2001-11-09        10/2002  ...         None    None    None
# 97    IGP-DI  2001-11-09        11/2002  ...         None    None    None
# 98    IGP-DI  2001-11-09        10/2001  ...         None    None    None
# 99    IGP-DI  2001-11-09        11/2001  ...         None    None    None
#
# [100 rows x 9 columns]
