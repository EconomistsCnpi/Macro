# %%
File link io

# %%
import pandas as pd 
dados_excel=pd.read_excel(io="https://aluno.analisemacro.com.br/download/45802/?tmstv=1672918970")
dados_excel
# Out:
#           data     pib
# 0   1996-01-01   99.55
# 1   1996-04-01  100.44
# 2   1996-07-01  104.38
# 3   1996-10-01  103.30
# 4   1997-01-01  104.32
# ..         ...     ...
# 100 2021-01-01  171.54
# 101 2021-04-01  171.17
# 102 2021-07-01  171.28
# 103 2021-10-01  172.41
# 104 2022-01-01  174.13
#
# [105 rows x 2 columns]

# %%
dados_excel=dados_excel.set_index('data').copy()
dados_excel.plot()
# Out:
# <Axes: xlabel='data'>

# %%
table=pd.read_excel(io='/home/eco/Downloads/pad14/dados/dados.xlsx',sheet_name=1)
table
# Out:
#           data  ibc_br
# 0   2003-01-01   96.15
# 1   2003-02-01   98.67
# 2   2003-03-01  103.41
# 3   2003-04-01  102.19
# 4   2003-05-01  100.30
# ..         ...     ...
# 233 2022-06-01  142.13
# 234 2022-07-01  149.62
# 235 2022-08-01  150.09
# 236 2022-09-01  145.26
# 237 2022-10-01  143.56
#
# [238 rows x 2 columns]

# %%
#Skip Line
table_pcamb=pd.read_excel('/home/eco/Downloads/pad14/dados/PcambBCp.xlsx', 
skiprows=9, 
nrows=183,
names=('ano','mes','reserva','estoque','swap','outros','total'),
header=None).dropna()
table_pcamb
# Out:
#         ano  mes        reserva       estoque           swap        outros  \
# 1    2008.0  Jan  187507.153378      0.000000   22181.689685    316.306128
# 13   2009.0  Jan  188101.650174  12711.431754  -12286.056405     -6.641141
# 25   2010.0  Jan  240483.527192    339.342454       0.000000  -4463.220233
# 37   2011.0  Jan  297696.449398      0.000000    3459.159990  -3070.360674
# 49   2012.0  Jan  355075.221307      0.000000    1415.084268  -4446.941180
# 61   2013.0  Jan  373416.523148   4420.000000   -1848.484681  -4114.367893
# 73   2014.0  Jan  360935.696068  14526.000000  -79197.869069  -4346.502927
# 85   2015.0  Jan  361767.128899  10400.000000 -114253.287748  -3912.956753
# 97   2016.0  Jan  357506.628064  12265.000000 -104462.186681  -3868.737311
# 109  2017.0  Jan  367708.174303   7200.000000  -26628.232152  -4053.196693
# 121  2018.0  Jan  375700.654713   8000.000000  -23822.499553  -4408.327241
# ...
